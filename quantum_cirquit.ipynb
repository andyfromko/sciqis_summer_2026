# %%
import numpy as np

# %%
def gate(gate, state):
    return gate@state

# %%
state_1 = np.array([[1],[0]])
state_2 = np.array([[1],[0]])

# %%
#single gays 
identity_gate = np.array([1,0,0,1]).reshape(2,2)

# %%
# Out:
# array([[1, 0],
#        [1, 0]])
